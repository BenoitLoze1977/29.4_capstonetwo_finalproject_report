# %%
from IPython.display import IFrame
IFrame(r"..\references\02_data_wrangling\1687275212_Capstone_Two_Step_2__Data_Wrangling.pdf", width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="..\references\02_data_wrangling\1687275212_Capstone_Two_Step_2__Data_Wrangling.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # 0. Content:

# %% [markdown]
# **TABLE of CONTENT:**
# [1. Capstone project introduction:](#1.-Capstone-project-introduction:)
# [2. Data wrangling:](#2.-Data-wrangling:)
#   - [2.1. Data collection:](#2.1.-Data-collection:)
#   - [2.2. Data organization:](#2.2.-Data-organization:)
#   - [2.3. Data definition:](#2.3.-Data-definition:)
#         - [2.3.1. General information:](#2.3.1.-General-information:)
#         - [2.3.2. Null values inspection:](#2.3.2.-Null-values-inspection:)
#         - [2.3.3. Time data:](#2.3.3.-Time-data:)
#         - [2.3.4. Categorical data:](#2.3.4.-Categorical-data:)
#         - [2.3.5. Columns description:](#2.3.5.-Columns-description:)
#         - [2.3.6. Redundant columns:](#2.3.6.-Redundant-columns:)
#         - [2.3.7. Duplicated rows:](#2.3.7.-Duplicated-rows:)
#         - [2.3.8. Ranges:](#2.3.8.-Ranges:)
#   - [2.4. Data cleaning:](#2.4.-Data-cleaning:)
#         - [2.4.1. Missing Values:](#2.4.1.-Missing-Values:)
#         - [2.4.2. Time data format:](#2.4.2.-Time-data-format:)
#         - [2.4.3. Categorical data:](#2.4.3.-Categorical-data:)
#         - [2.4.4. Outliers detection:](#2.4.4.-Outliers-detection:)
#         - [2.4.5. Redundant columns:](#2.4.4.-Redundant-columns:)
#         - [2.4.6. Duplicated rows:](#2.4.5.-Duplicated-rows:)
#         - [2.4.7. Ranges:](#2.4.6.-Ranges:)
#         - [2.4.8. Save dataframe to .csv:](#2.4.7.-Save-dataframe-to-.csv:)

# %% [markdown]
# # 1. Capstone project introduction:

# %% [markdown]
# **Project Overview: Building Permit Applications Analysis**
#
# **Description**
# Classifying Permit Types from San Francisco Building Permit Data Using Machine Learning.
#
# **Problem Statement**
# "Can a supervised machine learning model accurately classify San Francisco building permit types (e.g., New Construction, Additions/Alterations, Electrical) using structured features such as estimated cost, number of stories, zoning district, based on permit data from 2013 to 2018, and achieve at least 80% accuracy on a held-out test set within a 4-week project timeline?"
#
# **Dataset**
# - Title: San Francisco Building Permits.
# - Source: https://www.kaggle.com/datasets/aparnashastry/building-permit-applications-data?resource=download
# - Contents: The fields include:
#   - permit_type
#   - application_date
#   - estimated_cost
#   - status
#   - zipcode

# %% [markdown]
# # 2. Data wrangling:

# %% [markdown]
# ## 2.1. Data collection:

# %%
#!pip install thefuzz[speedup]

# %%
import pandas as pd
from thefuzz import fuzz
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
building_permits_path = r"../data/raw/Building_Permits.csv"

# %%
# .csv reading to dataframe:
sf_df = pd.read_csv(building_permits_path)
sf_df.head()
# Out:
# C:\Users\Benoit Loze\AppData\Local\Temp\ipykernel_4980\1073083552.py:2: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   sf_df = pd.read_csv(building_permits_path)
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# 1       Geary            St  ...                         3.0
# 2     Pacific            Av  ...                         1.0
# 3     Pacific            Av  ...                         5.0
# 4      Market            St  ...                         3.0
#
#   Existing Construction Type Description Proposed Construction Type  \
# 0                          constr type 3                        NaN
# 1                          constr type 3                        NaN
# 2                          constr type 1                        1.0
# 3                         wood frame (5)                        5.0
# 4                          constr type 3                        NaN
#
#   Proposed Construction Type Description Site Permit Supervisor District  \
# 0                                    NaN         NaN                 3.0
# 1                                    NaN         NaN                 3.0
# 2                          constr type 1         NaN                 3.0
# 3                         wood frame (5)         NaN                 3.0
# 4                                    NaN         NaN                 6.0
#
#   Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                          Tenderloin  94102.0
# 1                          Tenderloin  94102.0
# 2                        Russian Hill  94109.0
# 3                            Nob Hill  94109.0
# 4                          Tenderloin  94102.0
#
#                                     Location      Record ID
# 0  (37.785719256680785, -122.40852313194863)  1380611233945
# 1   (37.78733980600732, -122.41063199757738)  1420164406718
# 2    (37.7946573324287, -122.42232562979227)  1424856504716
# 3   (37.79595867909168, -122.41557405519474)  1443574295566
# 4   (37.78315261897309, -122.40950883997789)   144548169992
#
# [5 rows x 43 columns]

# %% [markdown]
# ## 2.2. Data organization:

# %% [markdown]
# **Cookiecutter Data Science** is a project template designed to standardize how data science projects are organized:
#
# - It helps start a project faster and on solid foundations by providing a predefined directory structure.
# - It makes it easier for project stakeholders to quickly understand the project layout, reducing confusion.
# - It clearly separates raw and processed data to improve reproducibility and workflow clarity.
#
# The folder structure was created locally using the `ccds` command in the command prompt (after installing the `cookiecutter-data-science` package via `pip`).
#
# The folder was then initialized as a local Git repository using the `git init` command.
#
# Finally, the local repository was published and pushed to GitHub.

# %% [markdown]
# ## 2.3. Data definition:

# %% [markdown]
# ### 2.3.1. General information:

# %%
# Total number of rows & columns:
sf_df.shape
# Out:
# (198900, 43)

# %%
# Column names, null data and data types:
sf_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198900 entries, 0 to 198899
# Data columns (total 43 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Permit Number                           198900 non-null  object
#  1   Permit Type                             198900 non-null  int64
#  2   Permit Type Definition                  198900 non-null  object
#  3   Permit Creation Date                    198900 non-null  object
#  4   Block                                   198900 non-null  object
#  5   Lot                                     198900 non-null  object
#  6   Street Number                           198900 non-null  int64
#  7   Street Number Suffix                    2216 non-null    object
#  8   Street Name                             198900 non-null  object
#  9   Street Suffix                           196132 non-null  object
#  10  Unit                                    29479 non-null   float64
#  11  Unit Suffix                             1961 non-null    object
#  12  Description                             198610 non-null  object
#  13  Current Status                          198900 non-null  object
#  14  Current Status Date                     198900 non-null  object
#  15  Filed Date                              198900 non-null  object
#  16  Issued Date                             183960 non-null  object
#  17  Completed Date                          97191 non-null   object
#  18  First Construction Document Date        183954 non-null  object
#  19  Structural Notification                 6922 non-null    object
#  20  Number of Existing Stories              156116 non-null  float64
#  21  Number of Proposed Stories              156032 non-null  float64
#  22  Voluntary Soft-Story Retrofit           35 non-null      object
#  23  Fire Only Permit                        18827 non-null   object
#  24  Permit Expiration Date                  147020 non-null  object
#  25  Estimated Cost                          160834 non-null  float64
#  26  Revised Cost                            192834 non-null  float64
#  27  Existing Use                            157786 non-null  object
#  28  Existing Units                          147362 non-null  float64
#  29  Proposed Use                            156461 non-null  object
#  30  Proposed Units                          147989 non-null  float64
#  31  Plansets                                161591 non-null  float64
#  32  TIDF Compliance                         2 non-null       object
#  33  Existing Construction Type              155534 non-null  float64
#  34  Existing Construction Type Description  155534 non-null  object
#  35  Proposed Construction Type              155738 non-null  float64
#  36  Proposed Construction Type Description  155738 non-null  object
#  37  Site Permit                             5359 non-null    object
#  38  Supervisor District                     197183 non-null  float64
#  39  Neighborhoods - Analysis Boundaries     197175 non-null  object
#  40  Zipcode                                 197184 non-null  float64
#  41  Location                                197200 non-null  object
#  42  Record ID                               198900 non-null  int64
# dtypes: float64(12), int64(3), object(28)
# memory usage: 65.3+ MB

# %%
sf_df_headers = list(sf_df.columns)
sf_df_headers
# Out:
# ['Permit Number',
#  'Permit Type',
#  'Permit Type Definition',
#  'Permit Creation Date',
#  'Block',
#  'Lot',
#  'Street Number',
#  'Street Number Suffix',
#  'Street Name',
#  'Street Suffix',
#  'Unit',
#  'Unit Suffix',
#  'Description',
#  'Current Status',
#  'Current Status Date',
#  'Filed Date',
#  'Issued Date',
#  'Completed Date',
#  'First Construction Document Date',
#  'Structural Notification',
#  'Number of Existing Stories',
#  'Number of Proposed Stories',
#  'Voluntary Soft-Story Retrofit',
#  'Fire Only Permit',
#  'Permit Expiration Date',
#  'Estimated Cost',
#  'Revised Cost',
#  'Existing Use',
#  'Existing Units',
#  'Proposed Use',
#  'Proposed Units',
#  'Plansets',
#  'TIDF Compliance',
#  'Existing Construction Type',
#  'Existing Construction Type Description',
#  'Proposed Construction Type',
#  'Proposed Construction Type Description',
#  'Site Permit',
#  'Supervisor District',
#  'Neighborhoods - Analysis Boundaries',
#  'Zipcode',
#  'Location',
#  'Record ID']

# %% [markdown]
# ### 2.3.2. Null values inspection:

# %%
# Info dataframe:
sf_df_info = pd.DataFrame({
    'column': sf_df.columns,
    'non_null_count': sf_df.notnull().sum().values,
    'null_count': sf_df.isnull().sum().values,
    'dtype': sf_df.dtypes.values
})

sf_df_info
# Out:
#                                     column  non_null_count  null_count  \
# 0                            Permit Number          198900           0
# 1                              Permit Type          198900           0
# 2                   Permit Type Definition          198900           0
# 3                     Permit Creation Date          198900           0
# 4                                    Block          198900           0
# 5                                      Lot          198900           0
# 6                            Street Number          198900           0
# 7                     Street Number Suffix            2216      196684
# 8                              Street Name          198900           0
# 9                            Street Suffix          196132        2768
# 10                                    Unit           29479      169421
# 11                             Unit Suffix            1961      196939
# 12                             Description          198610         290
# 13                          Current Status          198900           0
# 14                     Current Status Date          198900           0
# 15                              Filed Date          198900           0
# 16                             Issued Date          183960       14940
# 17                          Completed Date           97191      101709
# 18        First Construction Document Date          183954       14946
# 19                 Structural Notification            6922      191978
# 20              Number of Existing Stories          156116       42784
# 21              Number of Proposed Stories          156032       42868
# 22           Voluntary Soft-Story Retrofit              35      198865
# 23                        Fire Only Permit           18827      180073
# 24                  Permit Expiration Date          147020       51880
# 25                          Estimated Cost          160834       38066
# 26                            Revised Cost          192834        6066
# 27                            Existing Use          157786       41114
# 28                          Existing Units          147362       51538
# 29                            Proposed Use          156461       42439
# 30                          Proposed Units          147989       50911
# 31                                Plansets          161591       37309
# 32                         TIDF Compliance               2      198898
# 33              Existing Construction Type          155534       43366
# 34  Existing Construction Type Description          155534       43366
# 35              Proposed Construction Type          155738       43162
# 36  Proposed Construction Type Description          155738       43162
# 37                             Site Permit            5359      193541
# 38                     Supervisor District          197183        1717
# 39     Neighborhoods - Analysis Boundaries          197175        1725
# 40                                 Zipcode          197184        1716
# 41                                Location          197200        1700
# 42                               Record ID          198900           0
#
#       dtype
# 0    object
# 1     int64
# 2    object
# 3    object
# 4    object
# 5    object
# 6     int64
# 7    object
# 8    object
# 9    object
# 10  float64
# 11   object
# 12   object
# 13   object
# 14   object
# 15   object
# 16   object
# 17   object
# 18   object
# 19   object
# 20  float64
# 21  float64
# 22   object
# 23   object
# 24   object
# 25  float64
# 26  float64
# 27   object
# 28  float64
# 29   object
# 30  float64
# 31  float64
# 32   object
# 33  float64
# 34   object
# 35  float64
# 36   object
# 37   object
# 38  float64
# 39   object
# 40  float64
# 41   object
# 42    int64

# %%
# Column with Null values beyond 50% threshold:
threshold = round(sf_df.shape[0] * 0.5)
condition_null = sf_df_info["null_count"] > threshold
column_null_drop = sf_df_info.loc[condition_null, ["column", "null_count"]]
column_null_drop
# Out:
#                            column  null_count
# 7            Street Number Suffix      196684
# 10                           Unit      169421
# 11                    Unit Suffix      196939
# 17                 Completed Date      101709
# 19        Structural Notification      191978
# 22  Voluntary Soft-Story Retrofit      198865
# 23               Fire Only Permit      180073
# 32                TIDF Compliance      198898
# 37                    Site Permit      193541

# %%
# Columns for potential drop due to too many missing values:
null_drop = list(column_null_drop["column"])
null_drop
# Out:
# ['Street Number Suffix',
#  'Unit',
#  'Unit Suffix',
#  'Completed Date',
#  'Structural Notification',
#  'Voluntary Soft-Story Retrofit',
#  'Fire Only Permit',
#  'TIDF Compliance',
#  'Site Permit']

# %% [markdown]
# If the rows with null values in a feature represent less than 5% of the total records, those rows can be dropped.

# %%
# 5% rule:
five_percent = sf_df.shape[0] * 0.05
five_percent
# Out:
# 9945.0

# %%
condition_five_percent = (sf_df_info["null_count"] < five_percent) & (sf_df_info["null_count"] != 0)
columns_fivepercent = sf_df_info.loc[condition_five_percent, ["column", "null_count"]]
columns_fivepercent
# Out:
#                                  column  null_count
# 9                         Street Suffix        2768
# 12                          Description         290
# 26                         Revised Cost        6066
# 38                  Supervisor District        1717
# 39  Neighborhoods - Analysis Boundaries        1725
# 40                              Zipcode        1716
# 41                             Location        1700

# %%
fivepercent_drop = list(columns_fivepercent["column"])
fivepercent_drop
# Out:
# ['Street Suffix',
#  'Description',
#  'Revised Cost',
#  'Supervisor District',
#  'Neighborhoods - Analysis Boundaries',
#  'Zipcode',
#  'Location']

# %% [markdown]
# ### 2.3.3. Time data:

# %%
condition_date = sf_df_info["column"].str.lower().str.contains("date")

# %%
condition_date = sf_df_info["column"].str.lower().str.contains("date")
column_date_change = sf_df_info.loc[condition_date, ['column', 'dtype']]
column_date_change
# Out:
#                               column   dtype
# 3               Permit Creation Date  object
# 14               Current Status Date  object
# 15                        Filed Date  object
# 16                       Issued Date  object
# 17                    Completed Date  object
# 18  First Construction Document Date  object
# 24            Permit Expiration Date  object

# %%
# column for potential format change to date format:
date_change = list(column_date_change["column"])
date_change
# Out:
# ['Permit Creation Date',
#  'Current Status Date',
#  'Filed Date',
#  'Issued Date',
#  'Completed Date',
#  'First Construction Document Date',
#  'Permit Expiration Date']

# %% [markdown]
# ### 2.3.4. Categorical data:

# %% [markdown]
# Indentification of the potential categorical collumns. The purpose is to detect features with few unique values.
# Features with few unique values could be categorical despite being numeric (hot encoded).

# %%
for col in sf_df.columns:
    print(f"{col} - unique: {sf_df[col].nunique()} - dtype: {sf_df[col].dtype}")
# Out:
# Permit Number - unique: 181495 - dtype: object
# Permit Type - unique: 8 - dtype: int64
# Permit Type Definition - unique: 8 - dtype: object
# Permit Creation Date - unique: 1291 - dtype: object
# Block - unique: 4896 - dtype: object
# Lot - unique: 1055 - dtype: object
# Street Number - unique: 5099 - dtype: int64
# Street Number Suffix - unique: 18 - dtype: object
# Street Name - unique: 1704 - dtype: object
# Street Suffix - unique: 21 - dtype: object
# Unit - unique: 660 - dtype: float64
# Unit Suffix - unique: 164 - dtype: object
# Description - unique: 134272 - dtype: object
# Current Status - unique: 14 - dtype: object
# Current Status Date - unique: 1307 - dtype: object
# Filed Date - unique: 1288 - dtype: object
# Issued Date - unique: 1289 - dtype: object
# Completed Date - unique: 1300 - dtype: object
# First Construction Document Date - unique: 1288 - dtype: object
# Structural Notification - unique: 1 - dtype: object
# Number of Existing Stories - unique: 64 - dtype: float64
# Number of Proposed Stories - unique: 64 - dtype: float64
# Voluntary Soft-Story Retrofit - unique: 1 - dtype: object
# Fire Only Permit - unique: 1 - dtype: object
# Permit Expiration Date - unique: 2232 - dtype: object
# Estimated Cost - unique: 11395 - dtype: float64
# Revised Cost - unique: 12629 - dtype: float64
# Existing Use - unique: 93 - dtype: object
# Existing Units - unique: 348 - dtype: float64
# Proposed Use - unique: 94 - dtype: object
# Proposed Units - unique: 368 - dtype: float64
# Plansets - unique: 8 - dtype: float64
# TIDF Compliance - unique: 2 - dtype: object
# Existing Construction Type - unique: 5 - dtype: float64
# Existing Construction Type Description - unique: 5 - dtype: object
# Proposed Construction Type - unique: 5 - dtype: float64
# Proposed Construction Type Description - unique: 5 - dtype: object
# Site Permit - unique: 1 - dtype: object
# Supervisor District - unique: 11 - dtype: float64
# Neighborhoods - Analysis Boundaries - unique: 41 - dtype: object
# Zipcode - unique: 27 - dtype: float64
# Location - unique: 57604 - dtype: object
# Record ID - unique: 198900 - dtype: int64

# %%
# Exploration of Stories and Uses features:
columns_to_check = ["Number of Existing Stories", "Number of Proposed Stories", "Existing Use", "Proposed Use"]

for col in columns_to_check:
    print(f"\nColumn: {col}")
    
    # Drop missing values
    value_counts = sf_df[col].value_counts()
    
    # Calculate percentage
    percentages = (value_counts / len(sf_df)) * 100
    
    # Combine into a DataFrame
    summary = pd.DataFrame({
        'Value': value_counts.index,
        'Frequency': value_counts.values,
        'Percentage': percentages.round(2).values
    })

    print(summary)
# Out:
# Column: Number of Existing Stories
#     Value  Frequency  Percentage
# 0     2.0      52767       26.53
# 1     3.0      45740       23.00
# 2     4.0      16055        8.07
# 3     1.0       8793        4.42
# 4     5.0       3767        1.89
# ..    ...        ...         ...
# 59   49.0          3        0.00
# 60    2.5          2        0.00
# 61   62.0          2        0.00
# 62   78.0          1        0.00
# 63    1.5          1        0.00
#
# [64 rows x 3 columns]
#
# Column: Number of Proposed Stories
#     Value  Frequency  Percentage
# 0     2.0      50991       25.64
# 1     3.0      46802       23.53
# 2     4.0      17593        8.85
# 3     1.0       7893        3.97
# 4     5.0       4044        2.03
# ..    ...        ...         ...
# 59   47.0          3        0.00
# 60   49.0          3        0.00
# 61    2.5          2        0.00
# 62   78.0          1        0.00
# 63    1.5          1        0.00
#
# [64 rows x 3 columns]
#
# Column: Existing Use
#                    Value  Frequency  Percentage
# 0      1 family dwelling      46766       23.51
# 1             apartments      40798       20.51
# 2                 office      24616       12.38
# 3      2 family dwelling      20987       10.55
# 4           retail sales       6910        3.47
# ..                   ...        ...         ...
# 88                temple          2        0.00
# 89     roofing materials          1        0.00
# 90             orphanage          1        0.00
# 91  dairies/dairy equip.          1        0.00
# 92            child care          1        0.00
#
# [93 rows x 3 columns]
#
# Column: Proposed Use
#                    Value  Frequency  Percentage
# 0      1 family dwelling      46346       23.30
# 1             apartments      43032       21.63
# 2                 office      23962       12.05
# 3      2 family dwelling      22061       11.09
# 4           retail sales       5079        2.55
# ..                   ...        ...         ...
# 89                temple          2        0.00
# 90  dairies/dairy equip.          1        0.00
# 91     roofing materials          1        0.00
# 92             orphanage          1        0.00
# 93        not applicable          1        0.00
#
# [94 rows x 3 columns]

# %% [markdown]
# Let us fix a threshold at 100 to filter out the potential categorical features.

# %%
# Function defintion as operation repeated for numeric and text categories:
def categories(df, *dtype):

    # Constant categorical threshold:
    CATEGORICAL = 100

    # empty list:
    result = []

    # selection:
    for col in df.columns:
        if df[col].nunique() <= CATEGORICAL:
            if str(df[col].dtype) in dtype:
                tup = (col, df[col].nunique(), df[col].dtype)
                result.append(tup)

    return result

# %%
categories_numeric = categories(sf_df, 'int64', 'float64')
categories_numeric
# Out:
# [('Permit Type', 8, dtype('int64')),
#  ('Number of Existing Stories', 64, dtype('float64')),
#  ('Number of Proposed Stories', 64, dtype('float64')),
#  ('Plansets', 8, dtype('float64')),
#  ('Existing Construction Type', 5, dtype('float64')),
#  ('Proposed Construction Type', 5, dtype('float64')),
#  ('Supervisor District', 11, dtype('float64')),
#  ('Zipcode', 27, dtype('float64'))]

# %%
categories_text = categories(sf_df, 'object')
categories_text
# Out:
# [('Permit Type Definition', 8, dtype('O')),
#  ('Street Number Suffix', 18, dtype('O')),
#  ('Street Suffix', 21, dtype('O')),
#  ('Current Status', 14, dtype('O')),
#  ('Structural Notification', 1, dtype('O')),
#  ('Voluntary Soft-Story Retrofit', 1, dtype('O')),
#  ('Fire Only Permit', 1, dtype('O')),
#  ('Existing Use', 93, dtype('O')),
#  ('Proposed Use', 94, dtype('O')),
#  ('TIDF Compliance', 2, dtype('O')),
#  ('Existing Construction Type Description', 5, dtype('O')),
#  ('Proposed Construction Type Description', 5, dtype('O')),
#  ('Site Permit', 1, dtype('O')),
#  ('Neighborhoods - Analysis Boundaries', 41, dtype('O'))]

# %% [markdown]
# ### 2.3.5. Columns description:

# %% [markdown]
# The description of the columns content is directly available in a provided annex .xls file.

# %%
excel_url = "../data/raw/DataDictionaryBuildingPermit.xlsx"

# %%
description = pd.read_excel(excel_url, engine='openpyxl')
description
# Out:
#     Sl No                             Column name  \
# 0       1                           Permit Number
# 1       2                             Permit Type
# 2       3                  Permit Type Definition
# 3       4                    Permit Creation Date
# 4       5                                   Block
# 5       6                                     Lot
# 6       7                           Street Number
# 7       8                    Street Number Suffix
# 8       9                             Street Name
# 9      10                      Street Name Suffix
# 10     11                                    Unit
# 11     12                             Unit suffix
# 12     13                             Description
# 13     14                          Current Status
# 14     15                     Current Status Date
# 15     16                              Filed Date
# 16     17                             Issued Date
# 17     18                          Completed Date
# 18     19        First Construction Document Date
# 19     20                 Structural Notification
# 20     21              Number of Existing Stories
# 21     22              Number of Proposed Stories
# 22     23         Voluntary Soft-Story \nRetrofit
# 23     24                        Fire Only Permit
# 24     25                  Permit Expiration Date
# 25     26                          Estimated Cost
# 26     27                            Revised Cost
# 27     28                            Existing Use
# 28     29                          Existing Units
# 29     30                            Proposed Use
# 30     31                          Proposed Units
# 31     32                                Plansets
# 32     33                         TIDF Compliance
# 33     34              Existing Construction Type
# 34     35  Existing Construction Type Description
# 35     36              Proposed Construction Type
# 36     37  Proposed Construction Type Description
# 37     38                             Site Permit
# 38     39                     Supervisor District
# 39     40     Neighborhoods - Analysis Boundaries
# 40     41                                 Zipcode
# 41     42                                Location
# 42     43                               Record ID
#
#                                           Description
# 0                        Number assigned while filing
# 1         Type of the permit represented numerically.
# 2   Description of the Permit type, for example\n ...
# 3   Date on which permit created, later than \nor ...
# 4                                  Related to address
# 5                                  Related to address
# 6                                  Related to address
# 7                                  Related to address
# 8                                  Related to address
# 9                                  Related to address
# 10                                 Unit of a building
# 11                        Suffix if any, for the unit
# 12  Details about purpose of the permit.\n Example...
# 13         Current status of the permit application.
# 14           Date at which current status was entered
# 15                          Filed date for the permit
# 16                         Issued date for the permit
# 17  The date on which project was completed, \napp...
# 18          Date on which construction was documented
# 19  Notification to meet some legal need, given or...
# 20  Number of existing stories in the building. \n...
# 21  Number of proposed stories for the constructio...
# 22         Soft story to meet earth quake regulations
# 23              Fire hazard prevention related permit
# 24          Expiration date related to issued permit.
# 25      Initial estimation of the cost of the project
# 26      Revised estimation of the cost of the project
# 27                       Existing use of the building
# 28                           Existing number of units
# 29                       Proposed use of the building
# 30                           Proposed number of units
# 31  Plan representation indicating the general des...
# 32  TIDF compliant or not, this is a new legal req...
# 33  Construction type, existing,as categories \nre...
# 34  Description of the above, for example, \nwood ...
# 35  Construction type, proposed, as categories\n r...
# 36                           Description of the above
# 37                                    Permit for site
# 38  Supervisor District to which the building loca...
# 39  Neighborhood to which the building location be...
# 40                        Zipcode of building address
# 41              Location in latitude, longitude pair.
# 42                       Some ID, not useful for this

# %% [markdown]
# ### 2.3.6. Redundant columns:

# %% [markdown]
# Some descriptive columns, which describe already one-hot encoded variables, can be dropped from the main dataset and stored in a separate lookup table.
# They can be linked back to the main sf_df dataset via a shared primary key based on the one-hot code.
#  - Permit type definition.
#  - Existing construction type description.
#  - Proposed construction type description.

# %% [markdown]
# ### 2.3.7. Duplicated rows:

# %% [markdown]
# **Complete duplicates:**

# %%
complete_dups = sf_df[sf_df.duplicated(keep=False)]
complete_dups
# Out:
# Empty DataFrame
# Columns: [Permit Number, Permit Type, Permit Type Definition, Permit Creation Date, Block, Lot, Street Number, Street Number Suffix, Street Name, Street Suffix, Unit, Unit Suffix, Description, Current Status, Current Status Date, Filed Date, Issued Date, Completed Date, First Construction Document Date, Structural Notification, Number of Existing Stories, Number of Proposed Stories, Voluntary Soft-Story Retrofit, Fire Only Permit, Permit Expiration Date, Estimated Cost, Revised Cost, Existing Use, Existing Units, Proposed Use, Proposed Units, Plansets, TIDF Compliance, Existing Construction Type, Existing Construction Type Description, Proposed Construction Type, Proposed Construction Type Description, Site Permit, Supervisor District, Neighborhoods - Analysis Boundaries, Zipcode, Location, Record ID]
# Index: []
#
# [0 rows x 43 columns]

# %% [markdown]
# **Partial duplicates:**

# %%
subset_cols = ['Permit Number', 'Street Number', 'Street Name', 'Zipcode', 'Permit Type', 
               'Proposed Use', 'Issued Date', 'Current Status', 'Completed Date', 'Estimated Cost']
partial_dups = sf_df[sf_df.duplicated(subset=subset_cols, keep=False)]
partial_dups
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 18      201707283165            8            otc alterations permit
# 64      201711154040            3  additions alterations or repairs
# 77           M864527            8            otc alterations permit
# 84           M869807            8            otc alterations permit
# 133     201706018123            8            otc alterations permit
# ...              ...          ...                               ...
# 198631  201802221985            8            otc alterations permit
# 198654  201802221908            8            otc alterations permit
# 198770  201802232097            8            otc alterations permit
# 198771  201802232097            8            otc alterations permit
# 198772  201802232097            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# 18               07/28/2017  0472   042           1307                  NaN
# 64               11/15/2017  6969   001           5050                  NaN
# 77               12/08/2017  0642   087           1700                  NaN
# 84               12/22/2017  0474   036           1111                  NaN
# 133              06/01/2017  3606   085            240                  NaN
# ...                     ...   ...   ...            ...                  ...
# 198631           02/22/2018  3637   088           1170                  NaN
# 198654           02/22/2018  0311   008             88                  NaN
# 198770           02/23/2018  3117  049A            425                  NaN
# 198771           02/23/2018  3117  049A            425                    A
# 198772           02/23/2018  3117  049A            425                    B
#
#            Street Name Street Suffix  ...  Existing Construction Type  \
# 18                 Bay            St  ...                         5.0
# 64             Mission            St  ...                         NaN
# 77          California            St  ...                         NaN
# 84                 Bay            St  ...                         NaN
# 133            Liberty            St  ...                         5.0
# ...                ...           ...  ...                         ...
# 198631  South Van Ness            Av  ...                         5.0
# 198654          Kearny            St  ...                         1.0
# 198770        Monterey            Bl  ...                         5.0
# 198771        Monterey            Bl  ...                         5.0
# 198772        Monterey            Bl  ...                         5.0
#
#        Existing Construction Type Description Proposed Construction Type  \
# 18                             wood frame (5)                        5.0
# 64                                        NaN                        NaN
# 77                                        NaN                        NaN
# 84                                        NaN                        NaN
# 133                            wood frame (5)                        5.0
# ...                                       ...                        ...
# 198631                         wood frame (5)                        5.0
# 198654                          constr type 1                        1.0
# 198770                         wood frame (5)                        5.0
# 198771                         wood frame (5)                        5.0
# 198772                         wood frame (5)                        5.0
#
#        Proposed Construction Type Description Site Permit Supervisor District  \
# 18                             wood frame (5)         NaN                 2.0
# 64                                        NaN         NaN                11.0
# 77                                        NaN         NaN                 2.0
# 84                                        NaN         NaN                 2.0
# 133                            wood frame (5)         NaN                 8.0
# ...                                       ...         ...                 ...
# 198631                         wood frame (5)         NaN                 9.0
# 198654                          constr type 1         NaN                 3.0
# 198770                         wood frame (5)         NaN                 7.0
# 198771                         wood frame (5)         NaN                 7.0
# 198772                         wood frame (5)         NaN                 7.0
#
#        Neighborhoods - Analysis Boundaries  Zipcode  \
# 18                                  Marina  94123.0
# 64                           Outer Mission  94112.0
# 77                         Pacific Heights  94109.0
# 84                                  Marina  94123.0
# 133                    Castro/Upper Market  94114.0
# ...                                    ...      ...
# 198631                             Mission  94110.0
# 198654      Financial District/South Beach  94104.0
# 198770                  West of Twin Peaks  94112.0
# 198771                  West of Twin Peaks  94112.0
# 198772                  West of Twin Peaks  94112.0
#
#                                          Location      Record ID
# 18        (37.8035183252307, -122.42863180996076)  1472277302360
# 64       (37.71772263199437, -122.44060092814006)  1487232215636
# 77        (37.79055541147386, -122.4230298567197)   148986077468
# 84         (37.80383760408627, -122.425481726898)   149161771342
# 133     (37.757615513382525, -122.42667063025485)  1465253161623
# ...                                           ...            ...
# 198631    (37.75440724840337, -122.4168111100299)  1498083486988
# 198654   (37.78859990589228, -122.40331829649287)  1498106495355
# 198770   (37.73135521046475, -122.44488173732859)  1498224152794
# 198771   (37.73135521046475, -122.44488173732859)  1498225390708
# 198772   (37.73135521046475, -122.44488173732859)  1498226390709
#
# [3302 rows x 43 columns]

# %%
partial_dups_group = partial_dups.groupby(subset_cols).size().reset_index(name='Count')
partial_dups_group_sorted = partial_dups_group.sort_values(by='Count', ascending=False).head(10)
partial_dups_group_sorted
# Out:
#     Permit Number  Street Number        Street Name  Zipcode  Permit Type  \
# 393  201602179758            750           Kirkwood  94124.0            3
# 394  201602179758            780           Kirkwood  94124.0            3
# 395  201602179758            790           Kirkwood  94124.0            3
# 602  201707061162            260              Clara  94107.0            8
# 639  201711284975           1865         California  94109.0            8
# 442  201605127298              5  Burnett Ave North  94131.0            8
# 618  201709087418            738               06th  94118.0            8
# 446  201605177576            155            Hancock  94114.0            8
# 512  201610059572           2240              Green  94123.0            8
# 432  201604296147             50            Raymond  94134.0            8
#
#              Proposed Use Issued Date Current Status Completed Date  \
# 393            apartments  06/22/2016       complete     01/10/2017
# 394            apartments  06/22/2016       complete     01/10/2017
# 395            apartments  06/22/2016       complete     01/10/2017
# 602            apartments  07/31/2017       complete     01/09/2018
# 639            apartments  11/28/2017       complete     12/27/2017
# 442            apartments  05/12/2016       complete     06/13/2016
# 618            apartments  09/11/2017       complete     01/16/2018
# 446            apartments  05/17/2016       complete     10/03/2016
# 512            apartments  11/01/2016       complete     07/24/2017
# 432  public assmbly other  05/19/2017       complete     10/31/2017
#
#      Estimated Cost  Count
# 393         22682.0      8
# 394         22682.0      8
# 395         22682.0      8
# 602             1.0      8
# 639         18000.0      7
# 442         17780.0      6
# 618        110000.0      6
# 446         39000.0      5
# 512        129890.0      5
# 432        167200.0      5

# %% [markdown]
# ### 2.3.8. Ranges:

# %% [markdown]
# Several features could be summarized into ranges, which could help to understand the data distribution.
#  - Estimated Cost.
#  - Number of Existing Stories.
#  - Number of proposed Stories.
#  - Existing Units.
#  - Proposed Units.
#  - Filed Date.
#  - Zipcode.

# %% [markdown]
# ## 2.4. Data cleaning:

# %% [markdown]
# ### 2.4.1. Missing Values:

# %% [markdown]
# Drop of the features with more than 50% missing data.

# %%
sf_df.drop(columns=null_drop, inplace=True)
sf_df.shape
# Out:
# (198900, 34)

# %%
# Info dataframe:
sf_df_info = pd.DataFrame({
    'column': sf_df.columns,
    'non_null_count': sf_df.notnull().sum().values,
    'null_count': sf_df.isnull().sum().values,
    'dtype': sf_df.dtypes.values
})

sf_df_info
# Out:
#                                     column  non_null_count  null_count  \
# 0                            Permit Number          198900           0
# 1                              Permit Type          198900           0
# 2                   Permit Type Definition          198900           0
# 3                     Permit Creation Date          198900           0
# 4                                    Block          198900           0
# 5                                      Lot          198900           0
# 6                            Street Number          198900           0
# 7                              Street Name          198900           0
# 8                            Street Suffix          196132        2768
# 9                              Description          198610         290
# 10                          Current Status          198900           0
# 11                     Current Status Date          198900           0
# 12                              Filed Date          198900           0
# 13                             Issued Date          183960       14940
# 14        First Construction Document Date          183954       14946
# 15              Number of Existing Stories          156116       42784
# 16              Number of Proposed Stories          156032       42868
# 17                  Permit Expiration Date          147020       51880
# 18                          Estimated Cost          160834       38066
# 19                            Revised Cost          192834        6066
# 20                            Existing Use          157786       41114
# 21                          Existing Units          147362       51538
# 22                            Proposed Use          156461       42439
# 23                          Proposed Units          147989       50911
# 24                                Plansets          161591       37309
# 25              Existing Construction Type          155534       43366
# 26  Existing Construction Type Description          155534       43366
# 27              Proposed Construction Type          155738       43162
# 28  Proposed Construction Type Description          155738       43162
# 29                     Supervisor District          197183        1717
# 30     Neighborhoods - Analysis Boundaries          197175        1725
# 31                                 Zipcode          197184        1716
# 32                                Location          197200        1700
# 33                               Record ID          198900           0
#
#       dtype
# 0    object
# 1     int64
# 2    object
# 3    object
# 4    object
# 5    object
# 6     int64
# 7    object
# 8    object
# 9    object
# 10   object
# 11   object
# 12   object
# 13   object
# 14   object
# 15  float64
# 16  float64
# 17   object
# 18  float64
# 19  float64
# 20   object
# 21  float64
# 22   object
# 23  float64
# 24  float64
# 25  float64
# 26   object
# 27  float64
# 28   object
# 29  float64
# 30   object
# 31  float64
# 32   object
# 33    int64

# %% [markdown]
# Drop of the rows with missing data for less than 5% of its feature.

# %%
sf_df.dropna(subset=fivepercent_drop, inplace=True)

# %%
sf_df.shape
# Out:
# (188286, 34)

# %%
# Info dataframe:
sf_df_info = pd.DataFrame({
    'column': sf_df.columns,
    'non_null_count': sf_df.notnull().sum().values,
    'null_count': sf_df.isnull().sum().values,
    'dtype': sf_df.dtypes.values
})

sf_df_info
# Out:
#                                     column  non_null_count  null_count  \
# 0                            Permit Number          188286           0
# 1                              Permit Type          188286           0
# 2                   Permit Type Definition          188286           0
# 3                     Permit Creation Date          188286           0
# 4                                    Block          188286           0
# 5                                      Lot          188286           0
# 6                            Street Number          188286           0
# 7                              Street Name          188286           0
# 8                            Street Suffix          188286           0
# 9                              Description          188286           0
# 10                          Current Status          188286           0
# 11                     Current Status Date          188286           0
# 12                              Filed Date          188286           0
# 13                             Issued Date          179655        8631
# 14        First Construction Document Date          179648        8638
# 15              Number of Existing Stories          148010       40276
# 16              Number of Proposed Stories          148062       40224
# 17                  Permit Expiration Date          143847       44439
# 18                          Estimated Cost          151995       36291
# 19                            Revised Cost          188286           0
# 20                            Existing Use          149622       38664
# 21                          Existing Units          140002       48284
# 22                            Proposed Use          148468       39818
# 23                          Proposed Units          140605       47681
# 24                                Plansets          152229       36057
# 25              Existing Construction Type          147452       40834
# 26  Existing Construction Type Description          147452       40834
# 27              Proposed Construction Type          147781       40505
# 28  Proposed Construction Type Description          147781       40505
# 29                     Supervisor District          188286           0
# 30     Neighborhoods - Analysis Boundaries          188286           0
# 31                                 Zipcode          188286           0
# 32                                Location          188286           0
# 33                               Record ID          188286           0
#
#       dtype
# 0    object
# 1     int64
# 2    object
# 3    object
# 4    object
# 5    object
# 6     int64
# 7    object
# 8    object
# 9    object
# 10   object
# 11   object
# 12   object
# 13   object
# 14   object
# 15  float64
# 16  float64
# 17   object
# 18  float64
# 19  float64
# 20   object
# 21  float64
# 22   object
# 23  float64
# 24  float64
# 25  float64
# 26   object
# 27  float64
# 28   object
# 29  float64
# 30   object
# 31  float64
# 32   object
# 33    int64

# %% [markdown]
# Date and categorical data need their format to be corrected first. However, numeric data missing values can be imputed:
#     - Number of Existing Stories  --> mean.
#     - Number of Proposed Stories  --> mean.
#     - Existing Units  --> mean.
#     - Proposed Units  --> mean.
#     - Estimated Cost  --> median (data can be heavily skewed).

# %%
sf_df.fillna({
    "Number of Existing Stories": sf_df["Number of Existing Stories"].mean(),
    "Number of Proposed Stories": sf_df["Number of Proposed Stories"].mean(),
    "Existing Units": sf_df["Existing Units"].mean(),
    "Proposed Units": sf_df["Proposed Units"].mean(),
    "Estimated Cost": sf_df["Estimated Cost"].median()
}, inplace=True)

# %%
# Info dataframe:
sf_df_info = pd.DataFrame({
    'column': sf_df.columns,
    'non_null_count': sf_df.notnull().sum().values,
    'null_count': sf_df.isnull().sum().values,
    'dtype': sf_df.dtypes.values
})

sf_df_info
# Out:
#                                     column  non_null_count  null_count  \
# 0                            Permit Number          188286           0
# 1                              Permit Type          188286           0
# 2                   Permit Type Definition          188286           0
# 3                     Permit Creation Date          188286           0
# 4                                    Block          188286           0
# 5                                      Lot          188286           0
# 6                            Street Number          188286           0
# 7                              Street Name          188286           0
# 8                            Street Suffix          188286           0
# 9                              Description          188286           0
# 10                          Current Status          188286           0
# 11                     Current Status Date          188286           0
# 12                              Filed Date          188286           0
# 13                             Issued Date          179655        8631
# 14        First Construction Document Date          179648        8638
# 15              Number of Existing Stories          188286           0
# 16              Number of Proposed Stories          188286           0
# 17                  Permit Expiration Date          143847       44439
# 18                          Estimated Cost          188286           0
# 19                            Revised Cost          188286           0
# 20                            Existing Use          149622       38664
# 21                          Existing Units          188286           0
# 22                            Proposed Use          148468       39818
# 23                          Proposed Units          188286           0
# 24                                Plansets          152229       36057
# 25              Existing Construction Type          147452       40834
# 26  Existing Construction Type Description          147452       40834
# 27              Proposed Construction Type          147781       40505
# 28  Proposed Construction Type Description          147781       40505
# 29                     Supervisor District          188286           0
# 30     Neighborhoods - Analysis Boundaries          188286           0
# 31                                 Zipcode          188286           0
# 32                                Location          188286           0
# 33                               Record ID          188286           0
#
#       dtype
# 0    object
# 1     int64
# 2    object
# 3    object
# 4    object
# 5    object
# 6     int64
# 7    object
# 8    object
# 9    object
# 10   object
# 11   object
# 12   object
# 13   object
# 14   object
# 15  float64
# 16  float64
# 17   object
# 18  float64
# 19  float64
# 20   object
# 21  float64
# 22   object
# 23  float64
# 24  float64
# 25  float64
# 26   object
# 27  float64
# 28   object
# 29  float64
# 30   object
# 31  float64
# 32   object
# 33    int64

# %% [markdown]
# ### 2.4.2. Time data format:

# %% [markdown]
# The dropped date-related column is first removed from the list of columns to be processed as datetime data.
# The remaining datetime columns are then correctly parsed using pd.to_datetime() to ensure consistent format.
#
# In general, imputing missing datetime values requires caution, particularly if the analysis involves detecting temporal patterns or cycles.
# Simple mean or median imputation is not appropriate here, as these methods ignore chronological order and may introduce unrealistic or logically inconsistent dates.
# Forward filling, on the other hand, preserves temporal sequence and makes more sense — **but only if the data is first sorted**.
# Regarding logical relationships, columns such as `"Permit Creation Date"` and `"Filed Date"` are strongly tied to `"Permit Number"`. Therefore, grouping by `"Permit Number"` and sorting by each date column prior to forward filling might be a sound approach for imputing missing values in these columns.

# %%
date_change.remove('Completed Date')
date_change
# Out:
# ['Permit Creation Date',
#  'Current Status Date',
#  'Filed Date',
#  'Issued Date',
#  'First Construction Document Date',
#  'Permit Expiration Date']

# %%
sf_df[date_change]
# Out:
#        Permit Creation Date Current Status Date  Filed Date Issued Date  \
# 0                05/06/2015          12/21/2017  05/06/2015  11/09/2015
# 1                04/19/2016          08/03/2017  04/19/2016  08/03/2017
# 3                11/07/2016          07/24/2017  11/07/2016  07/18/2017
# 4                11/28/2016          12/01/2017  11/28/2016  12/01/2017
# 5                06/14/2017          07/06/2017  06/14/2017  07/06/2017
# ...                     ...                 ...         ...         ...
# 198881           02/23/2018          02/23/2018  02/23/2018  02/23/2018
# 198882           02/23/2018          02/23/2018  02/23/2018  02/23/2018
# 198883           02/23/2018          02/23/2018  02/23/2018  02/23/2018
# 198884           02/23/2018          02/23/2018  02/23/2018         NaN
# 198885           02/23/2018          02/23/2018  02/23/2018         NaN
#
#        First Construction Document Date Permit Expiration Date
# 0                            11/09/2015             11/03/2016
# 1                            08/03/2017             12/03/2017
# 3                            07/18/2017             07/13/2018
# 4                            11/20/2017             12/01/2018
# 5                            07/06/2017             07/01/2018
# ...                                 ...                    ...
# 198881                       02/23/2018                    NaN
# 198882                       02/23/2018             06/23/2018
# 198883                       02/23/2018                    NaN
# 198884                              NaN                    NaN
# 198885                              NaN                    NaN
#
# [188286 rows x 6 columns]

# %%
for col in date_change:
    sf_df[col] = pd.to_datetime(sf_df[col], infer_datetime_format=True, errors="coerce")
# Out:
# C:\Users\Benoit Loze\AppData\Local\Temp\ipykernel_4980\87832271.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sf_df[col] = pd.to_datetime(sf_df[col], infer_datetime_format=True, errors="coerce")
# C:\Users\Benoit Loze\AppData\Local\Temp\ipykernel_4980\87832271.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sf_df[col] = pd.to_datetime(sf_df[col], infer_datetime_format=True, errors="coerce")
# C:\Users\Benoit Loze\AppData\Local\Temp\ipykernel_4980\87832271.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sf_df[col] = pd.to_datetime(sf_df[col], infer_datetime_format=True, errors="coerce")
# C:\Users\Benoit Loze\AppData\Local\Temp\ipykernel_4980\87832271.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sf_df[col] = pd.to_datetime(sf_df[col], infer_datetime_format=True, errors="coerce")
# C:\Users\Benoit Loze\AppData\Local\Temp\ipykernel_4980\87832271.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sf_df[col] = pd.to_datetime(sf_df[col], infer_datetime_format=True, errors="coerce")
# C:\Users\Benoit Loze\AppData\Local\Temp\ipykernel_4980\87832271.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sf_df[col] = pd.to_datetime(sf_df[col], infer_datetime_format=True, errors="coerce")

# %%
# Info dataframe:
sf_df_info = pd.DataFrame({
    'column': sf_df.columns,
    'non_null_count': sf_df.notnull().sum().values,
    'null_count': sf_df.isnull().sum().values,
    'dtype': sf_df.dtypes.values
})

sf_df_info
# Out:
#                                     column  non_null_count  null_count  \
# 0                            Permit Number          188286           0
# 1                              Permit Type          188286           0
# 2                   Permit Type Definition          188286           0
# 3                     Permit Creation Date          188286           0
# 4                                    Block          188286           0
# 5                                      Lot          188286           0
# 6                            Street Number          188286           0
# 7                              Street Name          188286           0
# 8                            Street Suffix          188286           0
# 9                              Description          188286           0
# 10                          Current Status          188286           0
# 11                     Current Status Date          188286           0
# 12                              Filed Date          188286           0
# 13                             Issued Date          179655        8631
# 14        First Construction Document Date          179648        8638
# 15              Number of Existing Stories          188286           0
# 16              Number of Proposed Stories          188286           0
# 17                  Permit Expiration Date          143847       44439
# 18                          Estimated Cost          188286           0
# 19                            Revised Cost          188286           0
# 20                            Existing Use          149622       38664
# 21                          Existing Units          188286           0
# 22                            Proposed Use          148468       39818
# 23                          Proposed Units          188286           0
# 24                                Plansets          152229       36057
# 25              Existing Construction Type          147452       40834
# 26  Existing Construction Type Description          147452       40834
# 27              Proposed Construction Type          147781       40505
# 28  Proposed Construction Type Description          147781       40505
# 29                     Supervisor District          188286           0
# 30     Neighborhoods - Analysis Boundaries          188286           0
# 31                                 Zipcode          188286           0
# 32                                Location          188286           0
# 33                               Record ID          188286           0
#
#              dtype
# 0           object
# 1            int64
# 2           object
# 3   datetime64[ns]
# 4           object
# 5           object
# 6            int64
# 7           object
# 8           object
# 9           object
# 10          object
# 11  datetime64[ns]
# 12  datetime64[ns]
# 13  datetime64[ns]
# 14  datetime64[ns]
# 15         float64
# 16         float64
# 17  datetime64[ns]
# 18         float64
# 19         float64
# 20          object
# 21         float64
# 22          object
# 23         float64
# 24         float64
# 25         float64
# 26          object
# 27         float64
# 28          object
# 29         float64
# 30          object
# 31         float64
# 32          object
# 33           int64

# %%
# Control for ISO format:
sf_df[date_change]
# Out:
#        Permit Creation Date Current Status Date Filed Date Issued Date  \
# 0                2015-05-06          2017-12-21 2015-05-06  2015-11-09
# 1                2016-04-19          2017-08-03 2016-04-19  2017-08-03
# 3                2016-11-07          2017-07-24 2016-11-07  2017-07-18
# 4                2016-11-28          2017-12-01 2016-11-28  2017-12-01
# 5                2017-06-14          2017-07-06 2017-06-14  2017-07-06
# ...                     ...                 ...        ...         ...
# 198881           2018-02-23          2018-02-23 2018-02-23  2018-02-23
# 198882           2018-02-23          2018-02-23 2018-02-23  2018-02-23
# 198883           2018-02-23          2018-02-23 2018-02-23  2018-02-23
# 198884           2018-02-23          2018-02-23 2018-02-23         NaT
# 198885           2018-02-23          2018-02-23 2018-02-23         NaT
#
#        First Construction Document Date Permit Expiration Date
# 0                            2015-11-09             2016-11-03
# 1                            2017-08-03             2017-12-03
# 3                            2017-07-18             2018-07-13
# 4                            2017-11-20             2018-12-01
# 5                            2017-07-06             2018-07-01
# ...                                 ...                    ...
# 198881                       2018-02-23                    NaT
# 198882                       2018-02-23             2018-06-23
# 198883                       2018-02-23                    NaT
# 198884                              NaT                    NaT
# 198885                              NaT                    NaT
#
# [188286 rows x 6 columns]

# %%
date_columns = ["Permit Creation Date", "Filed Date"]

# Group by 'Permit Number' and forward-fill missing values for each date column
for col in date_columns:
    sf_df[col] = (sf_df.sort_values(['Permit Number', col]).groupby('Permit Number')[col].ffill())

# %%
sf_df_info = pd.DataFrame({
    'column': sf_df.columns,
    'non_null_count': sf_df.notnull().sum().values,
    'null_count': sf_df.isnull().sum().values,
    'dtype': sf_df.dtypes.values
})

sf_df_info
# Out:
#                                     column  non_null_count  null_count  \
# 0                            Permit Number          188286           0
# 1                              Permit Type          188286           0
# 2                   Permit Type Definition          188286           0
# 3                     Permit Creation Date          188286           0
# 4                                    Block          188286           0
# 5                                      Lot          188286           0
# 6                            Street Number          188286           0
# 7                              Street Name          188286           0
# 8                            Street Suffix          188286           0
# 9                              Description          188286           0
# 10                          Current Status          188286           0
# 11                     Current Status Date          188286           0
# 12                              Filed Date          188286           0
# 13                             Issued Date          179655        8631
# 14        First Construction Document Date          179648        8638
# 15              Number of Existing Stories          188286           0
# 16              Number of Proposed Stories          188286           0
# 17                  Permit Expiration Date          143847       44439
# 18                          Estimated Cost          188286           0
# 19                            Revised Cost          188286           0
# 20                            Existing Use          149622       38664
# 21                          Existing Units          188286           0
# 22                            Proposed Use          148468       39818
# 23                          Proposed Units          188286           0
# 24                                Plansets          152229       36057
# 25              Existing Construction Type          147452       40834
# 26  Existing Construction Type Description          147452       40834
# 27              Proposed Construction Type          147781       40505
# 28  Proposed Construction Type Description          147781       40505
# 29                     Supervisor District          188286           0
# 30     Neighborhoods - Analysis Boundaries          188286           0
# 31                                 Zipcode          188286           0
# 32                                Location          188286           0
# 33                               Record ID          188286           0
#
#              dtype
# 0           object
# 1            int64
# 2           object
# 3   datetime64[ns]
# 4           object
# 5           object
# 6            int64
# 7           object
# 8           object
# 9           object
# 10          object
# 11  datetime64[ns]
# 12  datetime64[ns]
# 13  datetime64[ns]
# 14  datetime64[ns]
# 15         float64
# 16         float64
# 17  datetime64[ns]
# 18         float64
# 19         float64
# 20          object
# 21         float64
# 22          object
# 23         float64
# 24         float64
# 25         float64
# 26          object
# 27         float64
# 28          object
# 29         float64
# 30          object
# 31         float64
# 32          object
# 33           int64

# %% [markdown]
# ### 2.4.3. Categorical data:

# %% [markdown]
# **Step 1**  - filtering & detection of fuzzy duplicated values:

# %%
# List of columns for numeric categories:
categories_numeric
# Out:
# [('Permit Type', 8, dtype('int64')),
#  ('Number of Existing Stories', 64, dtype('float64')),
#  ('Number of Proposed Stories', 64, dtype('float64')),
#  ('Plansets', 8, dtype('float64')),
#  ('Existing Construction Type', 5, dtype('float64')),
#  ('Proposed Construction Type', 5, dtype('float64')),
#  ('Supervisor District', 11, dtype('float64')),
#  ('Zipcode', 27, dtype('float64'))]

# %%
# List updating following columns dropping:
categories_numeric = [tup for tup in categories_numeric if tup[0] in sf_df.columns]
categories_numeric
# Out:
# [('Permit Type', 8, dtype('int64')),
#  ('Number of Existing Stories', 64, dtype('float64')),
#  ('Number of Proposed Stories', 64, dtype('float64')),
#  ('Plansets', 8, dtype('float64')),
#  ('Existing Construction Type', 5, dtype('float64')),
#  ('Proposed Construction Type', 5, dtype('float64')),
#  ('Supervisor District', 11, dtype('float64')),
#  ('Zipcode', 27, dtype('float64'))]

# %%
# "Zipcode" will treated as range values to determine district, regions, etc.
# same will happen for "Number of Existing Stories" and "Number of Proposed Stories"
values_to_remove = ["Number of Existing Stories", "Number of Proposed Stories", "Zipcode"]
categories_numeric = [x for x in categories_numeric if x[0] not in values_to_remove]
categories_numeric
# Out:
# [('Permit Type', 8, dtype('int64')),
#  ('Plansets', 8, dtype('float64')),
#  ('Existing Construction Type', 5, dtype('float64')),
#  ('Proposed Construction Type', 5, dtype('float64')),
#  ('Supervisor District', 11, dtype('float64'))]

# %%
# List of columns for text categories:
categories_text
# Out:
# [('Permit Type Definition', 8, dtype('O')),
#  ('Street Number Suffix', 18, dtype('O')),
#  ('Street Suffix', 21, dtype('O')),
#  ('Current Status', 14, dtype('O')),
#  ('Structural Notification', 1, dtype('O')),
#  ('Voluntary Soft-Story Retrofit', 1, dtype('O')),
#  ('Fire Only Permit', 1, dtype('O')),
#  ('Existing Use', 93, dtype('O')),
#  ('Proposed Use', 94, dtype('O')),
#  ('TIDF Compliance', 2, dtype('O')),
#  ('Existing Construction Type Description', 5, dtype('O')),
#  ('Proposed Construction Type Description', 5, dtype('O')),
#  ('Site Permit', 1, dtype('O')),
#  ('Neighborhoods - Analysis Boundaries', 41, dtype('O'))]

# %%
# List updating following columns dropping:
categories_text = [tup for tup in categories_text if tup[0] in sf_df.columns]
categories_text
# Out:
# [('Permit Type Definition', 8, dtype('O')),
#  ('Street Suffix', 21, dtype('O')),
#  ('Current Status', 14, dtype('O')),
#  ('Existing Use', 93, dtype('O')),
#  ('Proposed Use', 94, dtype('O')),
#  ('Existing Construction Type Description', 5, dtype('O')),
#  ('Proposed Construction Type Description', 5, dtype('O')),
#  ('Neighborhoods - Analysis Boundaries', 41, dtype('O'))]

# %% [markdown]
# Detection of potential fuzzy duplicates.
# No fuzzy duplicates detected.

# %%
# Detection of fuzzy duplicates in categorical values:
def detect_fuzzy_duplicates(df, text_col_stats, threshold=90):
    """
    Detect similar string values in categorical columns using fuzz.WRatio.

    Parameters:
    - df: pd.DataFrame
    - text_col_stats: list of tuples (col_name, unique_count, dtype)
    - threshold: int (fuzz.WRatio similarity threshold, default 90)

    Returns:
    - Dictionary: { column_name: [ (val1, val2, score), ... ] }
    """
    similar_values_dict = {}

    for col, _, _ in text_col_stats:
        values = df[col].dropna().astype(str).str.strip().unique().tolist()
        similar_pairs = []

        for i, val1 in enumerate(values):
            for j, val2 in enumerate(values):
                if i < j:
                    score = fuzz.WRatio(val1, val2)
                    if score >= threshold:
                        similar_pairs.append((val1, val2, score))

        if similar_pairs:
            similar_values_dict[col] = similar_pairs

    return similar_values_dict

# %%
categories_text_fuzzy = detect_fuzzy_duplicates(sf_df, categories_text)
categories_text_fuzzy
# Out:
# {'Permit Type Definition': [('new construction',
#    'new construction wood frame',
#    90)],
#  'Existing Use': [('1 family dwelling', '2 family dwelling', 94),
#   ('club', 'nite club', 90),
#   ('warehouse,no frnitur', 'warehouse, furniture', 90),
#   ('nursing home gt 6', 'nursing home lte 6', 91)],
#  'Proposed Use': [('1 family dwelling', '2 family dwelling', 94),
#   ('club', 'nite club', 90),
#   ('warehouse,no frnitur', 'warehouse, furniture', 90),
#   ('nursing home gt 6', 'nursing home lte 6', 91)],
#  'Existing Construction Type Description': [('constr type 3',
#    'constr type 1',
#    92),
#   ('constr type 3', 'constr type 4', 92),
#   ('constr type 3', 'constr type 2', 92),
#   ('constr type 1', 'constr type 4', 92),
#   ('constr type 1', 'constr type 2', 92),
#   ('constr type 4', 'constr type 2', 92)],
#  'Proposed Construction Type Description': [('constr type 1',
#    'constr type 3',
#    92),
#   ('constr type 1', 'constr type 4', 92),
#   ('constr type 1', 'constr type 2', 92),
#   ('constr type 3', 'constr type 4', 92),
#   ('constr type 3', 'constr type 2', 92),
#   ('constr type 4', 'constr type 2', 92)],
#  'Neighborhoods - Analysis Boundaries': [('Mission', 'Outer Mission', 90),
#   ('Mission', 'Mission Bay', 90),
#   ('Presidio Heights', 'Presidio', 90),
#   ('West of Twin Peaks', 'Twin Peaks', 90)]}

# %% [markdown]
# **Step 2** - conversion to category datatype:

# %%
categories = categories_numeric + categories_text
categories
# Out:
# [('Permit Type', 8, dtype('int64')),
#  ('Plansets', 8, dtype('float64')),
#  ('Existing Construction Type', 5, dtype('float64')),
#  ('Proposed Construction Type', 5, dtype('float64')),
#  ('Supervisor District', 11, dtype('float64')),
#  ('Permit Type Definition', 8, dtype('O')),
#  ('Street Suffix', 21, dtype('O')),
#  ('Current Status', 14, dtype('O')),
#  ('Existing Use', 93, dtype('O')),
#  ('Proposed Use', 94, dtype('O')),
#  ('Existing Construction Type Description', 5, dtype('O')),
#  ('Proposed Construction Type Description', 5, dtype('O')),
#  ('Neighborhoods - Analysis Boundaries', 41, dtype('O'))]

# %%
for tup in categories:
    sf_df[tup[0]] = sf_df[tup[0]].astype("category")

# %%
sf_df_info = pd.DataFrame({
    'column': sf_df.columns,
    'non_null_count': sf_df.notnull().sum().values,
    'null_count': sf_df.isnull().sum().values,
    'dtype': sf_df.dtypes.values
})

sf_df_info
# Out:
#                                     column  non_null_count  null_count  \
# 0                            Permit Number          188286           0
# 1                              Permit Type          188286           0
# 2                   Permit Type Definition          188286           0
# 3                     Permit Creation Date          188286           0
# 4                                    Block          188286           0
# 5                                      Lot          188286           0
# 6                            Street Number          188286           0
# 7                              Street Name          188286           0
# 8                            Street Suffix          188286           0
# 9                              Description          188286           0
# 10                          Current Status          188286           0
# 11                     Current Status Date          188286           0
# 12                              Filed Date          188286           0
# 13                             Issued Date          179655        8631
# 14        First Construction Document Date          179648        8638
# 15              Number of Existing Stories          188286           0
# 16              Number of Proposed Stories          188286           0
# 17                  Permit Expiration Date          143847       44439
# 18                          Estimated Cost          188286           0
# 19                            Revised Cost          188286           0
# 20                            Existing Use          149622       38664
# 21                          Existing Units          188286           0
# 22                            Proposed Use          148468       39818
# 23                          Proposed Units          188286           0
# 24                                Plansets          152229       36057
# 25              Existing Construction Type          147452       40834
# 26  Existing Construction Type Description          147452       40834
# 27              Proposed Construction Type          147781       40505
# 28  Proposed Construction Type Description          147781       40505
# 29                     Supervisor District          188286           0
# 30     Neighborhoods - Analysis Boundaries          188286           0
# 31                                 Zipcode          188286           0
# 32                                Location          188286           0
# 33                               Record ID          188286           0
#
#              dtype
# 0           object
# 1         category
# 2         category
# 3   datetime64[ns]
# 4           object
# 5           object
# 6            int64
# 7           object
# 8         category
# 9           object
# 10        category
# 11  datetime64[ns]
# 12  datetime64[ns]
# 13  datetime64[ns]
# 14  datetime64[ns]
# 15         float64
# 16         float64
# 17  datetime64[ns]
# 18         float64
# 19         float64
# 20        category
# 21         float64
# 22        category
# 23         float64
# 24        category
# 25        category
# 26        category
# 27        category
# 28        category
# 29        category
# 30        category
# 31         float64
# 32          object
# 33           int64

# %% [markdown]
# **Step 3** - missing values imputation:

# %% [markdown]
# Missing values can break downstream encoding processes.
# Imputing missing values in categorical features using the mode (most frequent value) is often considered the best default strategy in many practical scenarios.
# Since the mode is the most frequent value, using it reinforces the existing distribution rather than skewing it.

# %%
for col, _, _ in categories:
    mode_val = sf_df[col].mode(dropna=True)[0]  # [0] retrieves the first (most frequent) mode value from the Series.
    #print(mode_val)
    sf_df[col] = sf_df[col].fillna(mode_val)

# %%
sf_df_info = pd.DataFrame({
    'column': sf_df.columns,
    'non_null_count': sf_df.notnull().sum().values,
    'null_count': sf_df.isnull().sum().values,
    'dtype': sf_df.dtypes.values
})

sf_df_info
# Out:
#                                     column  non_null_count  null_count  \
# 0                            Permit Number          188286           0
# 1                              Permit Type          188286           0
# 2                   Permit Type Definition          188286           0
# 3                     Permit Creation Date          188286           0
# 4                                    Block          188286           0
# 5                                      Lot          188286           0
# 6                            Street Number          188286           0
# 7                              Street Name          188286           0
# 8                            Street Suffix          188286           0
# 9                              Description          188286           0
# 10                          Current Status          188286           0
# 11                     Current Status Date          188286           0
# 12                              Filed Date          188286           0
# 13                             Issued Date          179655        8631
# 14        First Construction Document Date          179648        8638
# 15              Number of Existing Stories          188286           0
# 16              Number of Proposed Stories          188286           0
# 17                  Permit Expiration Date          143847       44439
# 18                          Estimated Cost          188286           0
# 19                            Revised Cost          188286           0
# 20                            Existing Use          188286           0
# 21                          Existing Units          188286           0
# 22                            Proposed Use          188286           0
# 23                          Proposed Units          188286           0
# 24                                Plansets          188286           0
# 25              Existing Construction Type          188286           0
# 26  Existing Construction Type Description          188286           0
# 27              Proposed Construction Type          188286           0
# 28  Proposed Construction Type Description          188286           0
# 29                     Supervisor District          188286           0
# 30     Neighborhoods - Analysis Boundaries          188286           0
# 31                                 Zipcode          188286           0
# 32                                Location          188286           0
# 33                               Record ID          188286           0
#
#              dtype
# 0           object
# 1         category
# 2         category
# 3   datetime64[ns]
# 4           object
# 5           object
# 6            int64
# 7           object
# 8         category
# 9           object
# 10        category
# 11  datetime64[ns]
# 12  datetime64[ns]
# 13  datetime64[ns]
# 14  datetime64[ns]
# 15         float64
# 16         float64
# 17  datetime64[ns]
# 18         float64
# 19         float64
# 20        category
# 21         float64
# 22        category
# 23         float64
# 24        category
# 25        category
# 26        category
# 27        category
# 28        category
# 29        category
# 30        category
# 31         float64
# 32          object
# 33           int64

# %% [markdown]
# Update and check of the 5% percent threshold for missing values rows:

# %%
#Update of the 5% percent missing values for rows threshold:
missing_threshold = sf_df.shape[0] * 0.05
missing_threshold
# Out:
# 9414.300000000001

# %%
condition3 = (sf_df_info["null_count"] < missing_threshold)&(sf_df_info["null_count"] != 0)

# %%
columns5 = list(sf_df_info.loc[condition3, "column"])
sf_df = sf_df.dropna(subset=columns5)

# %%
sf_df_info = pd.DataFrame({
    'column': sf_df.columns,
    'non_null_count': sf_df.notnull().sum().values,
    'null_count': sf_df.isnull().sum().values,
    'dtype': sf_df.dtypes.values
})

sf_df_info
# Out:
#                                     column  non_null_count  null_count  \
# 0                            Permit Number          179623           0
# 1                              Permit Type          179623           0
# 2                   Permit Type Definition          179623           0
# 3                     Permit Creation Date          179623           0
# 4                                    Block          179623           0
# 5                                      Lot          179623           0
# 6                            Street Number          179623           0
# 7                              Street Name          179623           0
# 8                            Street Suffix          179623           0
# 9                              Description          179623           0
# 10                          Current Status          179623           0
# 11                     Current Status Date          179623           0
# 12                              Filed Date          179623           0
# 13                             Issued Date          179623           0
# 14        First Construction Document Date          179623           0
# 15              Number of Existing Stories          179623           0
# 16              Number of Proposed Stories          179623           0
# 17                  Permit Expiration Date          143799       35824
# 18                          Estimated Cost          179623           0
# 19                            Revised Cost          179623           0
# 20                            Existing Use          179623           0
# 21                          Existing Units          179623           0
# 22                            Proposed Use          179623           0
# 23                          Proposed Units          179623           0
# 24                                Plansets          179623           0
# 25              Existing Construction Type          179623           0
# 26  Existing Construction Type Description          179623           0
# 27              Proposed Construction Type          179623           0
# 28  Proposed Construction Type Description          179623           0
# 29                     Supervisor District          179623           0
# 30     Neighborhoods - Analysis Boundaries          179623           0
# 31                                 Zipcode          179623           0
# 32                                Location          179623           0
# 33                               Record ID          179623           0
#
#              dtype
# 0           object
# 1         category
# 2         category
# 3   datetime64[ns]
# 4           object
# 5           object
# 6            int64
# 7           object
# 8         category
# 9           object
# 10        category
# 11  datetime64[ns]
# 12  datetime64[ns]
# 13  datetime64[ns]
# 14  datetime64[ns]
# 15         float64
# 16         float64
# 17  datetime64[ns]
# 18         float64
# 19         float64
# 20        category
# 21         float64
# 22        category
# 23         float64
# 24        category
# 25        category
# 26        category
# 27        category
# 28        category
# 29        category
# 30        category
# 31         float64
# 32          object
# 33           int64

# %% [markdown]
# **Step4** - apply hot encoding:

# %% [markdown]
# Before applying hot encoding and to avoid multicollinearity, the "Description" columns will be extracted to a separated dataframe.

# %%
# List of columns to separate
description_cols = [
    'Permit Type Definition',
    'Existing Construction Type Description',
    'Proposed Construction Type Description'
]

# Extract description columns to a new DataFrame
description_df = sf_df[description_cols].copy()

# Drop them from main dataset
sf_df.drop(columns=description_cols, inplace=True)

# %%
sf_df_info = pd.DataFrame({
    'column': sf_df.columns,
    'non_null_count': sf_df.notnull().sum().values,
    'null_count': sf_df.isnull().sum().values,
    'dtype': sf_df.dtypes.values
})

sf_df_info
# Out:
#                                  column  non_null_count  null_count  \
# 0                         Permit Number          179623           0
# 1                           Permit Type          179623           0
# 2                  Permit Creation Date          179623           0
# 3                                 Block          179623           0
# 4                                   Lot          179623           0
# 5                         Street Number          179623           0
# 6                           Street Name          179623           0
# 7                         Street Suffix          179623           0
# 8                           Description          179623           0
# 9                        Current Status          179623           0
# 10                  Current Status Date          179623           0
# 11                           Filed Date          179623           0
# 12                          Issued Date          179623           0
# 13     First Construction Document Date          179623           0
# 14           Number of Existing Stories          179623           0
# 15           Number of Proposed Stories          179623           0
# 16               Permit Expiration Date          143799       35824
# 17                       Estimated Cost          179623           0
# 18                         Revised Cost          179623           0
# 19                         Existing Use          179623           0
# 20                       Existing Units          179623           0
# 21                         Proposed Use          179623           0
# 22                       Proposed Units          179623           0
# 23                             Plansets          179623           0
# 24           Existing Construction Type          179623           0
# 25           Proposed Construction Type          179623           0
# 26                  Supervisor District          179623           0
# 27  Neighborhoods - Analysis Boundaries          179623           0
# 28                              Zipcode          179623           0
# 29                             Location          179623           0
# 30                            Record ID          179623           0
#
#              dtype
# 0           object
# 1         category
# 2   datetime64[ns]
# 3           object
# 4           object
# 5            int64
# 6           object
# 7         category
# 8           object
# 9         category
# 10  datetime64[ns]
# 11  datetime64[ns]
# 12  datetime64[ns]
# 13  datetime64[ns]
# 14         float64
# 15         float64
# 16  datetime64[ns]
# 17         float64
# 18         float64
# 19        category
# 20         float64
# 21        category
# 22         float64
# 23        category
# 24        category
# 25        category
# 26        category
# 27        category
# 28         float64
# 29          object
# 30           int64

# %% [markdown]
# ### Hot encoding to be reserved for further stage!!

# %%
# cat_cols = sf_df.select_dtypes(include='category').columns

# # One-hot encode only the categorical columns.
# # 'drop_first=True' removes the first category level from each feature.
# # This is done to avoid multicollinearity, which can affect linear classification models.
# # such as logistic regression or linear SVM. It ensures that the encoded variables are independent.
# sf_df_dummies = pd.get_dummies(sf_df, columns=cat_cols, drop_first=True)

# %%
sf_df_dummies = sf_df

# %%
sf_df_dummies_info = pd.DataFrame({
    'column': sf_df_dummies.columns,
    'non_null_count': sf_df_dummies.notnull().sum().values,
    'null_count': sf_df_dummies.isnull().sum().values,
    'dtype': sf_df_dummies.dtypes.values
})

sf_df_dummies_info
# Out:
#                                  column  non_null_count  null_count  \
# 0                         Permit Number          179623           0
# 1                           Permit Type          179623           0
# 2                  Permit Creation Date          179623           0
# 3                                 Block          179623           0
# 4                                   Lot          179623           0
# 5                         Street Number          179623           0
# 6                           Street Name          179623           0
# 7                         Street Suffix          179623           0
# 8                           Description          179623           0
# 9                        Current Status          179623           0
# 10                  Current Status Date          179623           0
# 11                           Filed Date          179623           0
# 12                          Issued Date          179623           0
# 13     First Construction Document Date          179623           0
# 14           Number of Existing Stories          179623           0
# 15           Number of Proposed Stories          179623           0
# 16               Permit Expiration Date          143799       35824
# 17                       Estimated Cost          179623           0
# 18                         Revised Cost          179623           0
# 19                         Existing Use          179623           0
# 20                       Existing Units          179623           0
# 21                         Proposed Use          179623           0
# 22                       Proposed Units          179623           0
# 23                             Plansets          179623           0
# 24           Existing Construction Type          179623           0
# 25           Proposed Construction Type          179623           0
# 26                  Supervisor District          179623           0
# 27  Neighborhoods - Analysis Boundaries          179623           0
# 28                              Zipcode          179623           0
# 29                             Location          179623           0
# 30                            Record ID          179623           0
#
#              dtype
# 0           object
# 1         category
# 2   datetime64[ns]
# 3           object
# 4           object
# 5            int64
# 6           object
# 7         category
# 8           object
# 9         category
# 10  datetime64[ns]
# 11  datetime64[ns]
# 12  datetime64[ns]
# 13  datetime64[ns]
# 14         float64
# 15         float64
# 16  datetime64[ns]
# 17         float64
# 18         float64
# 19        category
# 20         float64
# 21        category
# 22         float64
# 23        category
# 24        category
# 25        category
# 26        category
# 27        category
# 28         float64
# 29          object
# 30           int64

# %%
sf_df_dummies.columns
# Out:
# Index(['Permit Number', 'Permit Type', 'Permit Creation Date', 'Block', 'Lot',
#        'Street Number', 'Street Name', 'Street Suffix', 'Description',
#        'Current Status', 'Current Status Date', 'Filed Date', 'Issued Date',
#        'First Construction Document Date', 'Number of Existing Stories',
#        'Number of Proposed Stories', 'Permit Expiration Date',
#        'Estimated Cost', 'Revised Cost', 'Existing Use', 'Existing Units',
#        'Proposed Use', 'Proposed Units', 'Plansets',
#        'Existing Construction Type', 'Proposed Construction Type',
#        'Supervisor District', 'Neighborhoods - Analysis Boundaries', 'Zipcode',
#        'Location', 'Record ID'],
#       dtype='object')

# %% [markdown]
# ### 2.4.4. Outliers detection:

# %% [markdown]
# **Step 1** - Columns identification & selection:

# %%
numerical_columns = sf_df_dummies.select_dtypes(include=[np.number]).columns.tolist()
numerical_columns
# Out:
# ['Street Number',
#  'Number of Existing Stories',
#  'Number of Proposed Stories',
#  'Estimated Cost',
#  'Revised Cost',
#  'Existing Units',
#  'Proposed Units',
#  'Zipcode',
#  'Record ID']

# %%
not_concerned = ["Street Number", "Zipcode", "Record ID"]

# %%
numerical_columns = [x for x in numerical_columns if x not in not_concerned]
numerical_columns
# Out:
# ['Number of Existing Stories',
#  'Number of Proposed Stories',
#  'Estimated Cost',
#  'Revised Cost',
#  'Existing Units',
#  'Proposed Units']

# %% [markdown]
# **Step 2** - Box plots:

# %%
# Create subplots: 3 rows x 2 columns
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 12))
#Flatten the axes 2D Numpy array to prepare below iteration:
axes = axes.flatten()  

# Loop through each numerical column and corresponding subplot
for i, col in enumerate(numerical_columns):
    sns.boxplot(data=sf_df_dummies, x=col, ax=axes[i], color='skyblue')
    axes[i].set_title(f'Boxplot of {col}', fontsize=12)

plt.savefig(r"..\reports\datawrangling_outliers_boxplots.png", dpi=300, bbox_inches="tight")

# Adjust layout for better appearance
plt.tight_layout()
plt.show()

# %% [markdown]
# **Step 3** - Inter quartile range:

# %%
# Function to detect outliers using IQR
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers[[column]]

# %%
# Check each column for outliers
for col in numerical_columns:
    outliers = detect_outliers_iqr(sf_df_dummies, col)
    print(f"{col}: {len(outliers)} outliers")
    
    if not outliers.empty:
        print("Top 5 most frequent outlier values:")
        print(outliers[col].value_counts().head(10), "\n")
# Out:
# Number of Existing Stories: 15528 outliers
# Top 5 most frequent outlier values:
# Number of Existing Stories
# 12.0    856
# 25.0    783
# 16.0    739
# 38.0    735
# 22.0    728
# 14.0    697
# 23.0    667
# 17.0    650
# 20.0    650
# 26.0    623
# Name: count, dtype: int64
#
# Number of Proposed Stories: 15470 outliers
# Top 5 most frequent outlier values:
# Number of Proposed Stories
# 12.0    861
# 25.0    764
# 16.0    734
# 38.0    717
# 22.0    711
# 14.0    704
# 23.0    657
# 26.0    650
# 17.0    646
# 20.0    643
# Name: count, dtype: int64
#
# Estimated Cost: 23777 outliers
# Top 5 most frequent outlier values:
# Estimated Cost
# 60000.0     1471
# 100000.0    1331
# 80000.0     1034
# 75000.0      975
# 150000.0     933
# 200000.0     723
# 70000.0      645
# 65000.0      615
# 250000.0     511
# 120000.0     493
# Name: count, dtype: int64
#
# Revised Cost: 23124 outliers
# Top 5 most frequent outlier values:
# Revised Cost
# 100000.0    1396
# 80000.0     1239
# 150000.0     970
# 75000.0      871
# 120000.0     672
# 200000.0     631
# 90000.0      590
# 250000.0     579
# 300000.0     411
# 85000.0      388
# Name: count, dtype: int64
#
# Existing Units: 9602 outliers
# Top 5 most frequent outlier values:
# Existing Units
# 156.0    222
# 48.0     221
# 45.0     197
# 38.0     183
# 448.0    178
# 42.0     174
# 63.0     165
# 54.0     158
# 39.0     149
# 50.0     148
# Name: count, dtype: int64
#
# Proposed Units: 9884 outliers
# Top 5 most frequent outlier values:
# Proposed Units
# 48.0     227
# 156.0    223
# 45.0     198
# 42.0     181
# 448.0    178
# 50.0     171
# 63.0     168
# 54.0     155
# 40.0     145
# 46.0     137
# Name: count, dtype: int64

# %%
outlier_counts = []
total_rows = sf_df_dummies.shape[0]

for col in numerical_columns:
    outliers = detect_outliers_iqr(sf_df_dummies, col)
    num_outliers = len(outliers)
    proportion = round((num_outliers / total_rows) * 100, 2)  # percentage with 2 decimals
    outlier_counts.append((col, num_outliers, proportion))

# Show the result
print(outlier_counts)
# Out:
# [('Number of Existing Stories', 15528, 8.64), ('Number of Proposed Stories', 15470, 8.61), ('Estimated Cost', 23777, 13.24), ('Revised Cost', 23124, 12.87), ('Existing Units', 9602, 5.35), ('Proposed Units', 9884, 5.5)]

# %% [markdown]
# **Step 4** - Distribution:

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

# Plot each histogram
for i, col in enumerate(numerical_columns):
    axes[i].hist(sf_df_dummies[col].dropna(), bins=50, edgecolor='black')
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Frequency')
    axes[i].grid(True)

plt.savefig(r"..\reports\datawrangling_outliers_distribution.png", dpi=300, bbox_inches="tight")

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# #### The numerical features have a highly skewed distribution due to the presence of outliers, which is not correct for machine learning model processing.

# %% [markdown]
# **Step 5** - Considerations:

# %% [markdown]
# The following considerations might be followed in further stage of EDA and data preprocessing:

# %% [markdown]
# | Outlier Proportion | Typical Action   | Explanation                                                              |
# |--------------------|------------------|---------------------------------------------------------------------------|
# | < 1%               | Safe to remove   | Negligible effect on model training and generalization                   |
# | 1–5%               | Often removable  | Still acceptable, especially if they are clear anomalies                 |
# | 5–15%              | Case-by-case     | Consider alternative handling (e.g., capping, transforming)              |
# | > 15%              | Caution!         | Removing this many records may bias the model or reduce generalization   |

# %%
for tup in outlier_counts:
    print(f"Feature '{tup[0]}' has {tup[1]} outliers, which is {tup[2]}% of the total feature records.")
# Out:
# Feature 'Number of Existing Stories' has 15528 outliers, which is 8.64% of the total feature records.
# Feature 'Number of Proposed Stories' has 15470 outliers, which is 8.61% of the total feature records.
# Feature 'Estimated Cost' has 23777 outliers, which is 13.24% of the total feature records.
# Feature 'Revised Cost' has 23124 outliers, which is 12.87% of the total feature records.
# Feature 'Existing Units' has 9602 outliers, which is 5.35% of the total feature records.
# Feature 'Proposed Units' has 9884 outliers, which is 5.5% of the total feature records.

# %% [markdown]
# ### 2.4.5. Redundant columns:

# %% [markdown]
# Some descriptive columns were extracted from the initial dataframe.
# This descriptive dataframe will saved as a distinct .csv file for future use.
# The most important is that "description_df" and "sf_df_dummies" keep aligned for any futher potential needed merge.

# %%
description_df.head(5)
# Out:
#    Permit Type Definition Existing Construction Type Description  \
# 0            sign - erect                          constr type 3
# 1            sign - erect                          constr type 3
# 3  otc alterations permit                         wood frame (5)
# 4             demolitions                          constr type 3
# 5  otc alterations permit                          constr type 1
#
#   Proposed Construction Type Description
# 0                         wood frame (5)
# 1                         wood frame (5)
# 3                         wood frame (5)
# 4                         wood frame (5)
# 5                          constr type 1

# %%
description_df.shape
# Out:
# (179623, 3)

# %%
sf_df_dummies.shape
# Out:
# (179623, 31)

# %% [markdown]
# **Save to local Github repository - To be transformed into comments for Springboard submission!**

# %%
# Save descriptive dataframe to local Github repository:
#description_df.to_csv(r"C:\Users\Benoit Loze\Desktop\SPRINGBOARD\_CURSUS\18_Data_Wrangling\18_06_Capstone_Two\18.6_capstone_two\data\interim\description_df.csv", index=False)

# %% [markdown]
# ### 2.4.6. Duplicated rows:

# %% [markdown]
# **Finding:**
#
# In the dataset, **no complete duplicated rows** were found. This means there are no rows where all columns are identical — so we do not need to remove any fully repeated entries.
#
# However, we did discover **several partial duplicates**. These are rows that are identical in a subset of important columns — such as `Permit Number`, `Street Name`, `Zipcode`, `Permit Type`, `Proposed Use`, etc. In many cases, the same `Permit Number` appears multiple times with small differences in other fields like `Issued Date`, `Completed Date`, `Current Status`, or `Estimated Cost`.
#
# ---
#
# **Reasons for partial duplicates:**
#
# Partial duplicates can occur for several reasons, especially in real-world administrative datasets like building permits:
#
# - **Permit updates**: A permit may be revised over time (e.g., a change in cost, schedule, or scope).
# - **Multiple phases**: One permit number might relate to different phases of a project, each recorded separately.
# - **Data entry inconsistencies**: Slight variations in status, dates, or descriptions may come from manual updates or parallel systems.
# - **Amendments or corrections**: Some permits may have been amended, resubmitted, or corrected, resulting in overlapping records.
#
# ---
#
# **Strategy:**
#
# At this **Data Wrangling** stage, we are **not making any deletions or assumptions**. Instead, we are **flagging these partial duplicates** and keeping them in mind for further investigation.
#
# We will revisit them during:
#
# - **Exploratory Data Analysis (EDA)** – to better understand their nature and distribution.
# - **Data Preprocessing** – to decide whether we need to merge them, keep the most recent one, or derive features from them.derive features from them.

# %% [markdown]
# ### 2.4.7. Ranges:

# %% [markdown]
# Several features have been identified as potenitally to be summarized into ranges, which could help to understand the data distribution.
#  - Estimated Cost.
#  - Number of Existing Stories.
#  - Number of proposed Stories.
#  - Existing Units.
#  - Proposed Units.
#  - Zipcode.

# %% [markdown]
# **Step1** - Ranges creations:

# %% [markdown]
# Estimated Cost:

# %%
cost_bins = [0, 10_000, 100_000, 500_000, 1_000_000, 5_000_000, np.inf]
cost_labels = ['<10k', '10k–100k', '100k–500k', '500k–1M', '1M–5M', '>5M']

sf_df_dummies['Estimated Cost Range'] = pd.cut(sf_df_dummies['Estimated Cost'], bins=cost_bins, labels=cost_labels)

# %% [markdown]
# Number of Existing Stories & Number of Proposed Stories:

# %%
story_bins = [0, 1, 3, 6, 10, 20, np.inf]
story_labels = ['1 story', '2–3 stories', '4–6', '7–10', '11–20', '21+']

sf_df_dummies['Existing Stories Range'] = pd.cut(sf_df_dummies['Number of Existing Stories'], bins=story_bins, labels=story_labels)
sf_df_dummies['Proposed Stories Range'] = pd.cut(sf_df_dummies['Number of Proposed Stories'], bins=story_bins, labels=story_labels)

# %% [markdown]
# Number of Existing Units & Number of Proposed Units:

# %%
unit_bins = [0, 1, 4, 10, 50, 200, np.inf]
unit_labels = ['0', '1–4', '5–10', '11–50', '51–200', '200+']

sf_df_dummies['Existing Units Range'] = pd.cut(sf_df_dummies['Existing Units'], bins=unit_bins, labels=unit_labels)
sf_df_dummies['Proposed Units Range'] = pd.cut(sf_df_dummies['Proposed Units'], bins=unit_bins, labels=unit_labels)

# %% [markdown]
# Filed Date:

# %%
# # Binning into decades:

# # Define bins and labels
# year_bins = [1990, 2000, 2010, 2020, 2025]
# year_labels = ['1990s', '2000s', '2010s', '2020+']

# # Bin the year extracted from 'Filed Date' directly
# sf_df_dummies['Filed Decade'] = pd.cut(sf_df_dummies['Filed Date'].dt.year, bins=year_bins, labels=year_labels)

# %% [markdown]
# **pd.cut() will not be used on "Zipcode" feature.**
# **Instead, we will group it in further stage by mapping it neighborhoods, districts, etc.**

# %% [markdown]
# **Step 3** - Control:

# %%
sf_df_dummies_info = pd.DataFrame({
    'column': sf_df_dummies.columns,
    'non_null_count': sf_df_dummies.notnull().sum().values,
    'null_count': sf_df_dummies.isnull().sum().values,
    'dtype': sf_df_dummies.dtypes.values
})

sf_df_dummies_info
# Out:
#                                  column  non_null_count  null_count  \
# 0                         Permit Number          179623           0
# 1                           Permit Type          179623           0
# 2                  Permit Creation Date          179623           0
# 3                                 Block          179623           0
# 4                                   Lot          179623           0
# 5                         Street Number          179623           0
# 6                           Street Name          179623           0
# 7                         Street Suffix          179623           0
# 8                           Description          179623           0
# 9                        Current Status          179623           0
# 10                  Current Status Date          179623           0
# 11                           Filed Date          179623           0
# 12                          Issued Date          179623           0
# 13     First Construction Document Date          179623           0
# 14           Number of Existing Stories          179623           0
# 15           Number of Proposed Stories          179623           0
# 16               Permit Expiration Date          143799       35824
# 17                       Estimated Cost          179623           0
# 18                         Revised Cost          179623           0
# 19                         Existing Use          179623           0
# 20                       Existing Units          179623           0
# 21                         Proposed Use          179623           0
# 22                       Proposed Units          179623           0
# 23                             Plansets          179623           0
# 24           Existing Construction Type          179623           0
# 25           Proposed Construction Type          179623           0
# 26                  Supervisor District          179623           0
# 27  Neighborhoods - Analysis Boundaries          179623           0
# 28                              Zipcode          179623           0
# 29                             Location          179623           0
# 30                            Record ID          179623           0
# 31                 Estimated Cost Range          179623           0
# 32               Existing Stories Range          179225         398
# 33               Proposed Stories Range          179480         143
# 34                 Existing Units Range          153940       25683
# 35                 Proposed Units Range          155737       23886
#
#              dtype
# 0           object
# 1         category
# 2   datetime64[ns]
# 3           object
# 4           object
# 5            int64
# 6           object
# 7         category
# 8           object
# 9         category
# 10  datetime64[ns]
# 11  datetime64[ns]
# 12  datetime64[ns]
# 13  datetime64[ns]
# 14         float64
# 15         float64
# 16  datetime64[ns]
# 17         float64
# 18         float64
# 19        category
# 20         float64
# 21        category
# 22         float64
# 23        category
# 24        category
# 25        category
# 26        category
# 27        category
# 28         float64
# 29          object
# 30           int64
# 31        category
# 32        category
# 33        category
# 34        category
# 35        category

# %%
ranges = ['Estimated Cost Range', 
          'Existing Stories Range', 
          'Proposed Stories Range', 
          'Existing Units Range', 
          'Proposed Units Range', 
         ]

# %%
for col in ranges:
    print(f"\nValue counts for '{col}':")
    print(sf_df_dummies[col].value_counts(dropna=False))
# Out:
# Value counts for 'Estimated Cost Range':
# Estimated Cost Range
# 10k–100k     93566
# <10k         72718
# 100k–500k     9623
# 500k–1M       1739
# 1M–5M         1671
# >5M            306
# Name: count, dtype: int64
#
# Value counts for 'Existing Stories Range':
# Existing Stories Range
# 2–3 stories    89326
# 4–6            59701
# 21+            10040
# 1 story         7837
# 11–20           6532
# 7–10            5789
# NaN              398
# Name: count, dtype: int64
#
# Value counts for 'Proposed Stories Range':
# Proposed Stories Range
# 2–3 stories    88864
# 4–6            61171
# 21+             9999
# 1 story         7188
# 11–20           6516
# 7–10            5742
# NaN              143
# Name: count, dtype: int64
#
# Value counts for 'Existing Units Range':
# Existing Units Range
# 11–50     58708
# 0         43741
# 1–4       32921
# NaN       25683
# 5–10      10786
# 51–200     5461
# 200+       2323
# Name: count, dtype: int64
#
# Value counts for 'Proposed Units Range':
# Proposed Units Range
# 11–50     58513
# 0         43625
# 1–4       34365
# NaN       23886
# 5–10      10911
# 51–200     5824
# 200+       2499
# Name: count, dtype: int64

# %% [markdown]
# **Step 4** - Hot encoding:

# %% [markdown]
# Once binned range columns are categorical.
# It will prepare the data for machine learning models.
# drop_first=True: removes the first category in each column to avoid multicollinearity for ML models.

# %%
# sf_df_encoded = pd.get_dummies(sf_df_dummies, columns=ranges, drop_first=True)

# %%
# sf_df_encoded_info = pd.DataFrame({
#     'column': sf_df_encoded.columns,
#     'non_null_count': sf_df_encoded.notnull().sum().values,
#     'null_count': sf_df_encoded.isnull().sum().values,
#     'dtype': sf_df_encoded.dtypes.values
# })

# sf_df_encoded_info

# %% [markdown]
# ### Hot encoding to be reserved for further stage!!

# %% [markdown]
# ### 2.4.8. Save dataframe to .csv:

# %% [markdown]
# **Save to local Github repository - To be transformed into comments for Springboard submission!**

# %%
sf_df_not_encoded = sf_df_dummies

# %%
sf_df_not_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 179623 entries, 0 to 198883
# Data columns (total 36 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Permit Number                        179623 non-null  object
#  1   Permit Type                          179623 non-null  category
#  2   Permit Creation Date                 179623 non-null  datetime64[ns]
#  3   Block                                179623 non-null  object
#  4   Lot                                  179623 non-null  object
#  5   Street Number                        179623 non-null  int64
#  6   Street Name                          179623 non-null  object
#  7   Street Suffix                        179623 non-null  category
#  8   Description                          179623 non-null  object
#  9   Current Status                       179623 non-null  category
#  10  Current Status Date                  179623 non-null  datetime64[ns]
#  11  Filed Date                           179623 non-null  datetime64[ns]
#  12  Issued Date                          179623 non-null  datetime64[ns]
#  13  First Construction Document Date     179623 non-null  datetime64[ns]
#  14  Number of Existing Stories           179623 non-null  float64
#  15  Number of Proposed Stories           179623 non-null  float64
#  16  Permit Expiration Date               143799 non-null  datetime64[ns]
#  17  Estimated Cost                       179623 non-null  float64
#  18  Revised Cost                         179623 non-null  float64
#  19  Existing Use                         179623 non-null  category
#  20  Existing Units                       179623 non-null  float64
#  21  Proposed Use                         179623 non-null  category
#  22  Proposed Units                       179623 non-null  float64
#  23  Plansets                             179623 non-null  category
#  24  Existing Construction Type           179623 non-null  category
#  25  Proposed Construction Type           179623 non-null  category
#  26  Supervisor District                  179623 non-null  category
#  27  Neighborhoods - Analysis Boundaries  179623 non-null  category
#  28  Zipcode                              179623 non-null  float64
#  29  Location                             179623 non-null  object
#  30  Record ID                            179623 non-null  int64
#  31  Estimated Cost Range                 179623 non-null  category
#  32  Existing Stories Range               179225 non-null  category
#  33  Proposed Stories Range               179480 non-null  category
#  34  Existing Units Range                 153940 non-null  category
#  35  Proposed Units Range                 155737 non-null  category
# dtypes: category(15), datetime64[ns](6), float64(7), int64(2), object(6)
# memory usage: 32.7+ MB

# %%
sf_df_not_encoded.to_csv(r"..\data\raw\sf_df_eda.csv", index=False)

# %%
# sf_df_encoded.to_csv(r"C:\Users\Benoit Loze\Desktop\SPRINGBOARD\_CURSUS\18_Data_Wrangling\18_06_Capstone_Two\18.6_capstone_two\data\interim\sf_df_encoded.csv", index=False)

# %%
#sf_df_not_encoded.to_csv(r"C:\Users\Benoit Loze\Desktop\SPRINGBOARD\_CURSUS\18_Data_Wrangling\18_06_Capstone_Two\18.6_capstone_two\data\interim\sf_df_not_encoded.csv", index=False)

# %%
# minimumd_date = sf_df_encoded["Filed Date"].min()
# minimumd_date

# %%
# minimumd_date = sf_df_encoded["Filed Date"].max()
# minimumd_date
